# %%
import time
import pyotp

def python_totp():
    # Replace "ninja@example.comHENNGECHALLENGE003" with your actual shared secret.
    shared_secret = "rbar0032@student.monash.eduHENNGECHALLENGE003"

    # Create a TOTP object with the shared secret
    totp = pyotp.TOTP(shared_secret, interval=30)

    # Get the current TOTP password
    totp_password = totp.now()

    print("TOTP Password:", totp_password)
    
    
python_totp()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[2], line 17
#      12     totp_password = totp.now()
#      14     print("TOTP Password:", totp_password)
# ---> 17 python_totp()
#
# Cell In[2], line 12, in python_totp()
#       9 totp = pyotp.TOTP(shared_secret, interval=30)
#      11 # Get the current TOTP password
# ---> 12 totp_password = totp.now()
#      14 print("TOTP Password:", totp_password)
#
# File ~/anaconda3/lib/python3.10/site-packages/pyotp/totp.py:64, in TOTP.now(self)
#      58 def now(self) -> str:
#      59     """
#      60     Generate the current time OTP
#      61
#      62     :returns: OTP value
#      63     """
# ---> 64     return self.generate_otp(self.timecode(datetime.datetime.now()))
#
# File ~/anaconda3/lib/python3.10/site-packages/pyotp/otp.py:35, in OTP.generate_otp(self, input)
#      33 if input < 0:
#      34     raise ValueError("input must be positive integer")
# ---> 35 hasher = hmac.new(self.byte_secret(), self.int_to_bytestring(input), self.digest)
#      36 hmac_hash = bytearray(hasher.digest())
#      37 offset = hmac_hash[-1] & 0xF
#
# File ~/anaconda3/lib/python3.10/site-packages/pyotp/otp.py:52, in OTP.byte_secret(self)
#      50 if missing_padding != 0:
#      51     secret += "=" * (8 - missing_padding)
# ---> 52 return base64.b32decode(secret, casefold=True)
#
# File ~/anaconda3/lib/python3.10/base64.py:253, in b32decode(s, casefold, map01)
#     252 def b32decode(s, casefold=False, map01=None):
# --> 253     return _b32decode(_b32alphabet, s, casefold, map01)
#
# File ~/anaconda3/lib/python3.10/base64.py:235, in _b32decode(alphabet, s, casefold, map01)
#     233             acc = (acc << 5) + b32rev[c]
#     234     except KeyError:
# --> 235         raise binascii.Error('Non-base32 digit found') from None
#     236     decoded += acc.to_bytes(5, 'big')
#     237 # Process the last, partial quanta
#
# Error: Non-base32 digit found

# %%
import base64
import pyotp
import hashlib  # Import hashlib to use the HMAC-SHA-512 hash function


def python_totp():
    # Replace "ninja@example.comHENNGECHALLENGE003" with your actual shared secret.
    shared_secret = "rbar0032@student.monash.eduHENNGECHALLENGE003"
    encoded_secret = base64.b32encode(shared_secret.encode()).decode()
    print("Base32 Encoded Secret:", shared_secret)

#     print("Base32 Encoded Secret:", encoded_secret)
    # Specify the number of digits for the TOTP password (e.g., 8 digits)
    digits = 10
    
    # Create a TOTP object with the shared secret
#     totp = pyotp.TOTP(shared_secret, interval=30, digits=digits, digest=hashlib.sha512)

    totp = pyotp.TOTP(encoded_secret, interval=30, digits=digits, digest=hashlib.sha512)

    # Get the current TOTP password
    totp_password = totp.now()

    print("TOTP Password:", totp_password)
    
python_totp()
# Out:
# Base32 Encoded Secret: rbar0032@student.monash.eduHENNGECHALLENGE003
# TOTP Password: 0231811043

# %%
import hmac
import hashlib
import struct
import base64
import pyotp
import time
import requests

#
# def generate_totp_password(shared_secret):
#     time_interval = 30
#     t0 = 0
#     current_time = int(time.time())
#     time_steps = (current_time - t0) // time_interval
#     time_steps_bytes = struct.pack(">Q", time_steps)
#
#     hmac_sha512 = hmac.new(shared_secret.encode(), time_steps_bytes, hashlib.sha512).digest()
#
#     offset = hmac_sha512[-1] & 0x0F
#     truncated_hash = hmac_sha512[offset:offset + 8]
#     totp_integer = struct.unpack(">Q", truncated_hash)[0]
#
#     mask = 0x7FFFFFFFFFFFFF  # 63 bits set to 1
#     totp_integer &= mask
#
#     return str(totp_integer % 10**10).zfill(10)

def generate_totp_password(shared_secret):
    time_interval = 30
    t0 = 0
    current_time = int(time.time())
    time_steps = (current_time - t0) // time_interval
    time_steps_bytes = struct.pack(">Q", time_steps)  # Use time_steps, not current_time

    hmac_sha512 = hmac.new(shared_secret.encode(), time_steps_bytes, hashlib.sha512).digest()

    offset = hmac_sha512[-1] & 0x0F
    truncated_hash = hmac_sha512[offset:offset + 8]
    totp_integer = struct.unpack(">Q", truncated_hash)[0]

    mask = 0x7FFFFFFFFFFFFF  # 63 bits set to 1
    totp_integer &= mask

    return str(totp_integer % 10**10).zfill(10)


import base64
import pyotp
import hashlib  # Import hashlib to use the HMAC-SHA-512 hash function


def python_totp():
    # Replace "ninja@example.comHENNGECHALLENGE003" with your actual shared secret.
    shared_secret = "rbar0032@student.monash.eduHENNGECHALLENGE003"
    encoded_secret = base64.b32encode(shared_secret.encode()).decode()
    print("Base32 Encoded Secret:", shared_secret)

    #     print("Base32 Encoded Secret:", encoded_secret)
    # Specify the number of digits for the TOTP password (e.g., 8 digits)
    digits = 10

    # Create a TOTP object with the shared secret
    #     totp = pyotp.TOTP(shared_secret, interval=30, digits=digits, digest=hashlib.sha512)

    totp = pyotp.TOTP(encoded_secret, interval=30, digits=digits, digest=hashlib.sha512)

    # Get the current TOTP password
    totp_password = totp.now()

    print("TOTP Password:", totp_password)

    return totp_password

def main():
    # Replace "ninja@example.comHENNGECHALLENGE003" with your actual shared secret.
    # shared_secret = "ninja@example.comHENNGECHALLENGE003"
    shared_secret = "rbar0032@student.monash.eduHENNGECHALLENGE003"
    # shared_secret = "rabchuunyuu@gmail.comHENNGECHALLENGE003"

    # totp_password = generate_totp_password(shared_secret)
    # Create a TOTP object with the shared secret
    # totp = pyotp.TOTP(shared_secret, interval=30)
    #
    # # Get the current TOTP password
    # totp_password = totp.now()

    totp_password = python_totp()
    print(totp_password)

    # Construct the HTTP Basic Authentication header value.
    # username = "ninja@example.com"
    username = "rbar0032@student.monash.edu"
    # username = "rabchuunyuu@gmail.com"
    combined_string = f"{username}:{totp_password}"
    auth_header_value = base64.b64encode(combined_string.encode()).decode()

    # The auth_header_value can be included in the "Authorization" header of your HTTP request.
    auth_header = f"Basic {auth_header_value}"
    print("Authorization Header:", auth_header)
    POST(auth_header)


def POST(auth_header):
    url = "https://api.challenge.hennge.com/challenges/003"
    headers = {
        "Authorization": auth_header,
        "Host": "api.challenge.hennge.com",
        "Accept": "*/*",
        "Content-Type": "application/json"
    }

    data = {"github_url": "https://gist.github.com/rbarmon/35d7fed1d7ee4e196fcef74d37f21fbe",
            "contact_email": "rbar0032@student.monash.edu", "solution_language": "python"}
    # data = {"github_url": "https://gist.github.com/rbarmon/35d7fed1d7ee4e196fcef74d37f21fbe",
    #         "contact_email": "rabchuunyuu@gmail.com", "solution_language": "python"}

    print(url)
    print(headers)
    print(data)

    response = requests.post(url, headers=headers, json=data)

    print("Status Code:", response.status_code)
    print("Response Content:", response.text)

# Authorization Header: Basic cmJhcjAwMzJAc3R1ZGVudC5tb25hc2guZWR1OjYyNjgzMjcyNTc=
# Authorization Header: Basic cmJhcjAwMzJAc3R1ZGVudC5tb25hc2guZWR1OjEwNjc5NTAxNjY=
# Authorization Header: Basic cmJhcjAwMzJAc3R1ZGVudC5tb25hc2guZWR1OjA0MzU0Njk3MDM=

# Authorization
# Header: Basic
# cmJhcjAwMzJAc3R1ZGVudC5tb25hc2guZWR1OjYyNjgzMjcyNTc =

if __name__ == '__main__':
    main()
# Out:
# Base32 Encoded Secret: rbar0032@student.monash.eduHENNGECHALLENGE003
# TOTP Password: 0213754455
# 0213754455
# Authorization Header: Basic cmJhcjAwMzJAc3R1ZGVudC5tb25hc2guZWR1OjAyMTM3NTQ0NTU=
# https://api.challenge.hennge.com/challenges/003
# {'Authorization': 'Basic cmJhcjAwMzJAc3R1ZGVudC5tb25hc2guZWR1OjAyMTM3NTQ0NTU=', 'Host': 'api.challenge.hennge.com', 'Accept': '*/*', 'Content-Type': 'application/json'}
# {'github_url': 'https://gist.github.com/rbarmon/35d7fed1d7ee4e196fcef74d37f21fbe', 'contact_email': 'rbar0032@student.monash.edu', 'solution_language': 'python'}
# Status Code: 200
# Response Content: {"message":"Congratulations! You have achieved mission 3"}
